# %% [markdown]
# <a href="https://colab.research.google.com/github/aanchaljain1993/Pandas_Practice_Project/blob/main/Census_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/file (8).csv')

# %% [markdown]
# # show all records of district is new delhi jaipur and lucknow

# %%
df[df['District_name'].isin(['New Delhi','Lucknow','Jaipur'])]
# Out:
#      District_code     State_name District_name  Population     Male   Female  \
# 93              94   NCT OF DELHI     New Delhi      142004    77942    64062
# 109            110      RAJASTHAN        Jaipur     6626178  3468507  3157671
# 156            157  UTTAR PRADESH       Lucknow     4589838  2394476  2195362
#
#      Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 93     114179    59541         46940           12601  ...        4852   2933
# 109   4300965  2464893       1714947          749946  ...       12708  18782
# 156   3127260  1542806       1226399          316407  ...       20493  23883
#
#      Buddhists  Jains  Secondary_Education  Higher_Education  \
# 93         312    679                15942             17742
# 109       1020  81079               659389            455527
# 156       3877   4975               428121            378742
#
#      Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50
# ...

# %% [markdown]
# calculate state wise
#
# total number of population
#
#
# total numbe of popltion of all religion

# %%
df.groupby('State_name')['Population'].sum()
# Out:
# State_name
# ANDAMAN AND NICOBAR ISLANDS       380581
# ANDHRA PRADESH                  84580777
# ARUNACHAL PRADESH                1383727
# ASSAM                           31205576
# BIHAR                          104099452
# CHANDIGARH                       1055450
# CHHATTISGARH                    25545198
# DADRA AND NAGAR HAVELI            343709
# DAMAN AND DIU                     243247
# GOA                              1458545
# GUJARAT                         60439692
# HARYANA                         25351462
# HIMACHAL PRADESH                 6864602
# JAMMU AND KASHMIR               12541302
# JHARKHAND                       32988134
# KARNATAKA                       61095297
# KERALA                          33406061
# LAKSHADWEEP                        64473
# MADHYA PRADESH                  72626809
# MAHARASHTRA                    112374333
# MANIPUR                          2855794
# MEGHALAYA                        2966889
# ...

# %%
df.groupby('State_name')[['Christians','Sikhs','Buddhists']].sum()
# Out:
#                              Christians     Sikhs  Buddhists
# State_name
# ANDAMAN AND NICOBAR ISLANDS       80984      1286        338
# ANDHRA PRADESH                  1129784     40244      36692
# ARUNACHAL PRADESH                418732      3287     162815
# ASSAM                           1165867     20672      54993
# BIHAR                            129247     23779      25453
# CHANDIGARH                         8720    138329       1160
# CHHATTISGARH                     490542     70036      70467
# DADRA AND NAGAR HAVELI             5113       217        634
# DAMAN AND DIU                      2820       172        217
# GOA                              366130      1473       1095
# GUJARAT                          316178     58246      30483
# HARYANA                           50353   1243752       7514
# HIMACHAL PRADESH                  12646     79896      78659
# JAMMU AND KASHMIR                 35631    234848     112584
# ...

# %% [markdown]
# # how many male in maharshtar

# %%
df[df['State_name']=='MAHARASHTRA']['Male'].sum()
# Out:
# 58243056

# %% [markdown]
# # how to make index district code

# %%
df.set_index('District_code')
# Out:
#                                 State_name              District_name  \
# District_code
# 1                        JAMMU AND KASHMIR                    Kupwara
# 2                        JAMMU AND KASHMIR                     Badgam
# 3                        JAMMU AND KASHMIR                Leh(Ladakh)
# 4                        JAMMU AND KASHMIR                     Kargil
# 5                        JAMMU AND KASHMIR                      Punch
# ...                                    ...                        ...
# 636                            PONDICHERRY                       Mahe
# 637                            PONDICHERRY                   Karaikal
# 638            ANDAMAN AND NICOBAR ISLANDS                   Nicobars
# 639            ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman
# 640            ANDAMAN AND NICOBAR ISLANDS              South Andaman
#
#                Population    Male  Female  Literate  Workers  Male_Workers  \
# District_code
# ...
